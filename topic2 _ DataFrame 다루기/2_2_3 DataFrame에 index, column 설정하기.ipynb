# %% [markdown]
# # 데이터 index, cloumn 설정

# %%
# !pip install IPython 
from IPython.display import Image
import pandas as pd
liverpool_df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/liverpool.csv', index_col = 0)
liverpool_df
# Out:
# ...
#                 position  born  number nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %% [markdown]
# ## Columns 이름 설정

# %%
liverpool_df.rename(columns = {'position': 'Position'}, inplace = True)
liverpool_df
# Out:
#                 Position  born  number nationality
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %% [markdown]
# ### 인덱스 column 명 설정

# %%
liverpool_df.index.name = 'Player Name'
liverpool_df
# Out:
#                 Position  born  number nationality
# Player Name
# Roberto Firmino       FW  1991   no. 9      Brazil
# Sadio Mane            FW  1992  no. 10     Senegal
# Mohamed Salah         FW  1992  no. 11       Egypt
# Joe Gomez             DF  1997  no. 12     England
# Alisson Becker        GK  1992  no. 13      Brazil

# %% [markdown]
# ## 인덱스 바꾸기

# %%
liverpool_df.set_index('number')
# Out:
#        Position  born nationality
# number
# no. 9        FW  1991      Brazil
# no. 10       FW  1992     Senegal
# no. 11       FW  1992       Egypt
# no. 12       DF  1997     England
# no. 13       GK  1992      Brazil

# %% [markdown]
# - number로 인덱스를 바꾸면 원래 인덱스가 날아가 버림 그래서 추가해주고 인덱스 바꾸기

# %%
liverpool_df['Player Name'] = liverpool_df.index
liverpool_df
# Out:
#                 Position  born  number nationality      Player Name
# Player Name
# Roberto Firmino       FW  1991   no. 9      Brazil  Roberto Firmino
# Sadio Mane            FW  1992  no. 10     Senegal       Sadio Mane
# Mohamed Salah         FW  1992  no. 11       Egypt    Mohamed Salah
# Joe Gomez             DF  1997  no. 12     England        Joe Gomez
# Alisson Becker        GK  1992  no. 13      Brazil   Alisson Becker

# %%
liverpool_df.set_index('number', inplace = True)
liverpool_df
# Out:
#        Position  born nationality      Player Name
# number
# no. 9        FW  1991      Brazil  Roberto Firmino
# no. 10       FW  1992     Senegal       Sadio Mane
# no. 11       FW  1992       Egypt    Mohamed Salah
# no. 12       DF  1997     England        Joe Gomez
# no. 13       GK  1992      Brazil   Alisson Becker

# %% [markdown]
# - 인덱스는 중복되지 않는 값으로 설정하는것이 좋음

# %% [markdown]
# ## 실습과제 _ 서류 전형 합격 여부
#
# 토익 시험은 LC(듣기) 파트와 RC(독해) 파트로 이루어져 있습니다. 각 파트가 495점 만점, 총 990점이 만점입니다.
#
# “서울 항공”에 입사하기 위해서는 토익 점수를 제출해야 하는데요. 각 파트가 최소 250점, 총 점수가 최소 600점이 되어야 서류 전형을 합격할 수 있습니다.
#
# 기존 DataFrame에 “합격 여부”라는 column을 추가하고, 합격한 지원자는 불린 값 True, 불합격한 지원자는 불린 값 False를 넣어주면 됩니다.

# %%
df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/toeic.csv', index_col = 0)
df
# Out:
#          LC   RC
# Gender
# female  315  320
# female  430  245
# female  430  475
# male    180  220
# male    325  350
# female  295  400
# female  405  475
# male    155  150
# male    280  315
# female  215  475

# %%
df['합격 여부'] = ((df['LC'] + df['RC'])>=600) & (df['RC'] >= 250) & (df['LC']>=250)
df
# Out:
#          LC   RC  합격 여부
# Gender
# female  315  320   True
# female  430  245  False
# female  430  475   True
# male    180  220  False
# male    325  350   True
# female  295  400   True
# female  405  475   True
# male    155  150  False
# male    280  315  False
# female  215  475  False

# %% [markdown]
# ## 실습과제 _ 퍼즐을 풀어라
#
# 아래 사진과같은 데이터프레임이 있습니다.

# %%
Image('C:/Users/jaewoo/Desktop/data science/data/1.png')

# %% [markdown]
# 코드를 4줄만 써서, 아래 데이터프레임으로 바꿔보세요.

# %%
Image('C:/Users/jaewoo/Desktop/data science/data/2.png')

# %%
df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/Puzzle_before.csv')

df['A'] = df['A'] * 2
df.loc[:, 'B':'E'] = df.loc[:, 'B':'E'] >= 80
df.loc[2, 'F'] = 99

df * 1
# Out:
#     A  B  C  D  E   F
# 0   2  0  0  1  0  13
# 1   4  0  0  1  0  24
# 2   6  1  0  1  0  99
# 3   8  1  1  0  1  78
# 4  10  0  1  0  1  61
