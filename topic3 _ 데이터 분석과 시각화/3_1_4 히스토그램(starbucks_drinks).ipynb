# %% [markdown]
# # 히스토그램(kind = 'hist')

# %%
# %matplotlib inline
import pandas as pd

# 어도비(Adobe)의 직원 분포를 한번 살펴봅시다. 어도비 전체 직원들의 직군 분포를 파이 그래프로 그려보세요.
df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/body.csv',index_col = 0)
df.head(10)
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# 6        175.4    72.7
# 7        181.5    87.9
# 8        174.2    64.5
# 9        176.4    57.5
# 10       175.8    66.4

# %%
df.plot(kind='hist', y='Height')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='hist', y='Height', bins = 15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 실습과제 _ 스타벅스 음료의 칼로리는? 1
#
# 실습과제
# 스타벅스 음료의 칼로리 및 영양소 정보가 있습니다.
#
# 스타벅스 음료의 칼로리 분포는 어떻게 되는지, 히스토그램을 그려서 확인해 봅시다.
#
# 원하는 결과가 나오도록 df.plot() 메소드의 괄호를 채워 보세요!
#
# df.plot()  괄호를 채워 주세요.
#
# 칼로리의 구간은 총 20개로 나누어 주세요.

# %%
# %matplotlib inline
import pandas as pd

# 스타벅스 음료의 칼로리 분포는 어떻게 되는지, 히스토그램을 그려서 확인해 봅시다.
df = pd.read_csv('C:/Users/Kwon JaeWoo/Desktop/codeit_데이터사이언스 입문/3_5starbucks_drinks.csv')
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 214  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 215  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 216  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 217  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 218  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
# Calories(칼로리)의 히스토그램을 출력, 
df.plot(kind = 'hist', y = 'Calories', bins = 20) # 빈도 = 20
# Out:
# <AxesSubplot:ylabel='Frequency'>
