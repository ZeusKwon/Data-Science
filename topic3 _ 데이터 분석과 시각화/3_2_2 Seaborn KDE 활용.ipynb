# %% [markdown]
# # Seaborn KDE 활용
#
# - 히스토그램 seaborn

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/body.csv',index_col = 0)
df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
df.plot(kind='hist', y = 'Height',bins= 15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(df['Height'], bins =15)
# Out:
# <AxesSubplot:xlabel='Height'>

# %% [markdown]
# - 박스플롯 seaborn

# %%
df.plot(kind='box', y = 'Height')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(y = df['Height'])
# Out:
# <AxesSubplot:ylabel='Height'>

# %% [markdown]
# - 산점도 seaborn

# %%
df.plot(kind = 'scatter', x = 'Height', y = 'Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(df['Height'], df['Weight'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(df['Height'])
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['Weight'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 실습과제 _ 교수님의 연봉은?
#
# 교수가 꿈인 지훈이는 교수들의 급여 분포를 알아보려고 합니다.
#
# 인터넷에서 어느 학교 교수의 급여 데이터를 발견했네요!
#
# 급여 ('salary')에 대한 Violin Plot을 그려 보세요.

# %%
sa_df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/salaries.csv',index_col = 0)
sa_df.head()
# Out:
#      discipline  yrs.since.phd  yrs.service   sex  salary
# rank
# Prof          B             56           49  Male  186960
# Prof          A             12            6  Male   93000
# Prof          A             23           20  Male  110515
# Prof          A             40           31  Male  131205
# Prof          B             20           18  Male  104800

# %%
sns.violinplot(x = sa_df['salary'])
# Out:
# <AxesSubplot:xlabel='salary'>

# %% [markdown]
# ## Seaborn Lm plot(회귀선)

# %%
sns.lmplot(data = df, x = 'Height', y = 'Weight')

# %%
df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/laptops.csv')
df.head()
# Out:
#    brand             model  ram hd_type  hd_size  screen_size   price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1  Apple       MacBook Air    8     ssd      128         13.3   55499
# 2  Apple       MacBook Air    8     ssd      256         13.3   71500
# 3  Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4  Apple       MacBook Pro    8     ssd      256         13.3  112666
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
# 3           intel              i5          2.3              intel
# 4           intel              i5          2.3              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# ...

# %%
df['os'].unique()
# Out:
# array(['linux', 'mac', 'windows'], dtype=object)

# %%
sns.catplot(data = df, x = 'os', y = 'price', kind = 'box')

# %%
sns.catplot(data = df, x = 'os', y = 'price', kind = 'violin')

# %%
sns.catplot(data = df, x = 'os', y = 'price', kind = 'strip')

# %%
df['processor_brand'].unique()
# Out:
# array(['intel', 'amd'], dtype=object)

# %%
sns.catplot(data = df, x = 'os', y = 'price', kind = 'strip', hue = 'processor_brand')

# %%
sns.catplot(data = df, x = 'os', y = 'price', kind = 'swarm', hue = 'processor_brand')

# %% [markdown]
# ## 실습과제 _ 보험금 분석하기
#
# 실습과제
# 보험 회사에서 보험금이 어떻게 지출되었는지 분석하려고 합니다.
#
# 다음과 같이 흡연 여부 카테고리에 따라 보험금을 살펴볼 수 있는 그래프를 그려보세요.

# %%
df = pd.read_csv('C:/Users/jaewoo/Desktop/data science/data/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.catplot(data = df, x = 'smoker', y = 'charges', kind = 'violin')
